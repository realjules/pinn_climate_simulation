# %% [markdown]
# ### Evaluating East Africa Model

# %%
# !python evaluation_region.py --spectral 0 --scale 0 --region EastAfrica --batch_size 8 --model_path "\\tests\\region\\east africa\\baseline\\ClimODE_region_EastAfrica_euler_0_model_80.pt"
# Out:
# ^C
# ############################ Data is loading ###########################
# ['c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/geopotential_500/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/temperature_850/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/2m_temperature/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/10m_u_component_of_wind/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/10m_v_component_of_wind/*.nc']
# Length of training data 1460
# Length of validation data 1460
# Length of testing data 1460
# ClimODE_uncertain_region(
#   (vel_f): Climate_ResNet_2D(
#     (layer_cnn): ModuleList(
#       (0): Sequential(
#         (0): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (2): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (3): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (4): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (2): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (2): Sequential(
#         (0): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Conv2d(64, 10, kernel_size=(1, 1), stride=(1, 1))
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#     )
#     (activation_cnn): ModuleList()
#   )
#   (vel_att): Self_attn_conv_reg(
#     (query): Sequential(
#       (0): boundarypad()
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.3)
#       (3): boundarypad()
#       (4): Conv2d(32, 8, kernel_size=(3, 3), stride=(1, 1))
#       (5): LeakyReLU(negative_slope=0.3)
#       (6): boundarypad()
#       (7): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     )
#     (key): Sequential(
#       (0): boundarypad()
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2))
#       (2): LeakyReLU(negative_slope=0.3)
#       (3): boundarypad()
#       (4): Conv2d(32, 8, kernel_size=(3, 3), stride=(2, 2))
#       (5): LeakyReLU(negative_slope=0.3)
#       (6): boundarypad()
#       (7): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     )
#     (value): Sequential(
#       (0): boundarypad()
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2))
#       (2): LeakyReLU(negative_slope=0.3)
#       (3): boundarypad()
#       (4): Conv2d(32, 10, kernel_size=(3, 3), stride=(2, 2))
#       (5): LeakyReLU(negative_slope=0.3)
#       (6): boundarypad()
#       (7): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#     )
#     (post_map): Sequential(
#       (0): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (noise_net): Climate_ResNet_2D(
#     (layer_cnn): ModuleList(
#       (0): Sequential(
#         (0): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(43, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Conv2d(43, 128, kernel_size=(1, 1), stride=(1, 1))
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (2): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (2): Sequential(
#         (0): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Conv2d(64, 10, kernel_size=(1, 1), stride=(1, 1))
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): ResidualBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (drop): Dropout(p=0.1, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#     )
#     (activation_cnn): ModuleList()
#   )
# )
# Lead Time 6 hours | Observable z | Mean RMSD 55.64147553723907 | Std RMSD 14.7774920633779
# Lead Time 6 hours | Observable z | Mean ACC 0.886868767724558 | Std ACC 0.09280673831169552
# Lead Time 6 hours | Observable z | Mean CRPS 0.01335979126598671 | Std CRPS 0.008732320961876188
# Lead Time 6 hours | Observable t | Mean RMSD 0.9522484772824696 | Std RMSD 0.15236944398490854
# Lead Time 6 hours | Observable t | Mean ACC 0.9388322847516352 | Std ACC 0.04003043414321853
# Lead Time 6 hours | Observable t | Mean CRPS 0.014349900638426484 | Std CRPS 0.012426288704619044
# Lead Time 6 hours | Observable t2m | Mean RMSD 1.4503962699361614 | Std RMSD 0.37116472766074715
# Lead Time 6 hours | Observable t2m | Mean ACC 0.8860769603834455 | Std ACC 0.06762547083932548
# Lead Time 6 hours | Observable t2m | Mean CRPS 0.017345039326676477 | Std CRPS 0.016644839325924095
# Lead Time 6 hours | Observable u10 | Mean RMSD 1.471030780602485 | Std RMSD 0.2593222433907276
# Lead Time 6 hours | Observable u10 | Mean ACC 0.7547746212302291 | Std ACC 0.11148932481584477
# Lead Time 6 hours | Observable u10 | Mean CRPS 0.019654092122465824 | Std CRPS 0.016864730671202
# Lead Time 6 hours | Observable v10 | Mean RMSD 1.5223491766718698 | Std RMSD 0.2378420965520147
# Lead Time 6 hours | Observable v10 | Mean ACC 0.8028212583063656 | Std ACC 0.09869696768224158
# Lead Time 6 hours | Observable v10 | Mean CRPS 0.02586224806125445 | Std CRPS 0.02180808406566637
# Lead Time 12 hours | Observable z | Mean RMSD 74.89098794066597 | Std RMSD 23.948002608450757
# Lead Time 12 hours | Observable z | Mean ACC 0.8429462386570196 | Std ACC 0.14364679158332164
# Lead Time 12 hours | Observable z | Mean CRPS 0.0181828736478554 | Std CRPS 0.013171082176555934
# Lead Time 12 hours | Observable t | Mean RMSD 1.189379261688011 | Std RMSD 0.19718398307853355
# Lead Time 12 hours | Observable t | Mean ACC 0.8905253413820806 | Std ACC 0.07831349316729735
# Lead Time 12 hours | Observable t | Mean CRPS 0.017967887461209458 | Std CRPS 0.016046786506687966
# Lead Time 12 hours | Observable t2m | Mean RMSD 1.742937103104743 | Std RMSD 0.48175065923820426
# Lead Time 12 hours | Observable t2m | Mean ACC 0.8503943822817156 | Std ACC 0.09892014377758193
# Lead Time 12 hours | Observable t2m | Mean CRPS 0.020574979022249636 | Std CRPS 0.020338952072556628
# Lead Time 12 hours | Observable u10 | Mean RMSD 1.5589058894811318 | Std RMSD 0.3272994859487347
# Lead Time 12 hours | Observable u10 | Mean ACC 0.7068472360927943 | Std ACC 0.1361278454064579
# Lead Time 12 hours | Observable u10 | Mean CRPS 0.020681172073464614 | Std CRPS 0.01840223993884141
# Lead Time 12 hours | Observable v10 | Mean RMSD 1.6965515653099872 | Std RMSD 0.2722169889039722
# Lead Time 12 hours | Observable v10 | Mean ACC 0.7450332696897386 | Std ACC 0.1302851921826215
# Lead Time 12 hours | Observable v10 | Mean CRPS 0.028893787669695217 | Std CRPS 0.02521094297710474
# Lead Time 18 hours | Observable z | Mean RMSD 81.64956747849773 | Std RMSD 25.027966151173032
# Lead Time 18 hours | Observable z | Mean ACC 0.7742696727165885 | Std ACC 0.18532603836070694
# Lead Time 18 hours | Observable z | Mean CRPS 0.019312015390019147 | Std CRPS 0.015022193350932554
# Lead Time 18 hours | Observable t | Mean RMSD 1.3509048700752466 | Std RMSD 0.24860757314012563
# Lead Time 18 hours | Observable t | Mean ACC 0.8497098652676963 | Std ACC 0.09948498853603288
# Lead Time 18 hours | Observable t | Mean CRPS 0.02051617754023476 | Std CRPS 0.01869265950060427
# Lead Time 18 hours | Observable t2m | Mean RMSD 1.818220059638597 | Std RMSD 0.42747409536345515
# Lead Time 18 hours | Observable t2m | Mean ACC 0.7929486349847902 | Std ACC 0.17064554199212192
# Lead Time 18 hours | Observable t2m | Mean CRPS 0.0219237009703247 | Std CRPS 0.02104727886967397
# Lead Time 18 hours | Observable u10 | Mean RMSD 1.574290039505683 | Std RMSD 0.34617929192698493
# Lead Time 18 hours | Observable u10 | Mean ACC 0.7415929574217579 | Std ACC 0.12794442255330188
# Lead Time 18 hours | Observable u10 | Mean CRPS 0.020882769439816408 | Std CRPS 0.019651577939467264
# Lead Time 18 hours | Observable v10 | Mean RMSD 1.673523739593547 | Std RMSD 0.3395115988820636
# Lead Time 18 hours | Observable v10 | Mean ACC 0.7590834622235473 | Std ACC 0.14703122267107324
# Lead Time 18 hours | Observable v10 | Mean CRPS 0.028069947877102125 | Std CRPS 0.02740730063763293
# Lead Time 24 hours | Observable z | Mean RMSD 86.41531892376325 | Std RMSD 30.138904977072716
# Lead Time 24 hours | Observable z | Mean ACC 0.7768937297187555 | Std ACC 0.18043026198370432
# Lead Time 24 hours | Observable z | Mean CRPS 0.020593888651826583 | Std CRPS 0.017263082484846756
# Lead Time 24 hours | Observable t | Mean RMSD 1.3850010141752997 | Std RMSD 0.27897990237206
# Lead Time 24 hours | Observable t | Mean ACC 0.8845839280378621 | Std ACC 0.08317444996922553
# Lead Time 24 hours | Observable t | Mean CRPS 0.021023515130165607 | Std CRPS 0.01986778754695497
# Lead Time 24 hours | Observable t2m | Mean RMSD 1.7345539431807284 | Std RMSD 0.36883428626149023
# Lead Time 24 hours | Observable t2m | Mean ACC 0.8957320585835407 | Std ACC 0.06586741187599551
# Lead Time 24 hours | Observable t2m | Mean CRPS 0.020225759817896958 | Std CRPS 0.020746860608392263
# Lead Time 24 hours | Observable u10 | Mean RMSD 1.4205083660322375 | Std RMSD 0.30638797778490984
# Lead Time 24 hours | Observable u10 | Mean ACC 0.7889420757595264 | Std ACC 0.11163272282157206
# Lead Time 24 hours | Observable u10 | Mean CRPS 0.01851834222726528 | Std CRPS 0.017848970161557922
# Lead Time 24 hours | Observable v10 | Mean RMSD 1.5964196267678166 | Std RMSD 0.3360671623274333
# Lead Time 24 hours | Observable v10 | Mean ACC 0.7819101909835228 | Std ACC 0.1437211957213816
# Lead Time 24 hours | Observable v10 | Mean CRPS 0.026868723742906036 | Std CRPS 0.026212765583026803
# Lead Time 30 hours | Observable z | Mean RMSD 104.05990950460527 | Std RMSD 35.44485073964279
# Lead Time 30 hours | Observable z | Mean ACC 0.6856935685930615 | Std ACC 0.24347111997824358
# Lead Time 30 hours | Observable z | Mean CRPS 0.02482308772207818 | Std CRPS 0.02124767330528233
# Lead Time 30 hours | Observable t | Mean RMSD 1.6518189355591961 | Std RMSD 0.3182829594068926
# Lead Time 30 hours | Observable t | Mean ACC 0.8144109656110717 | Std ACC 0.1432767173835069
# Lead Time 30 hours | Observable t | Mean CRPS 0.0255945143371983 | Std CRPS 0.024047494499903427
# Lead Time 30 hours | Observable t2m | Mean RMSD 1.8801158660491848 | Std RMSD 0.4595324930825301
# Lead Time 30 hours | Observable t2m | Mean ACC 0.7829137197431455 | Std ACC 0.1519531087745759
# Lead Time 30 hours | Observable t2m | Mean CRPS 0.022871807663717467 | Std CRPS 0.02316811802323623
# Lead Time 30 hours | Observable u10 | Mean RMSD 1.641652517454421 | Std RMSD 0.32829618823186535
# Lead Time 30 hours | Observable u10 | Mean ACC 0.652008396008297 | Std ACC 0.17015284957569365
# Lead Time 30 hours | Observable u10 | Mean CRPS 0.021929730406428677 | Std CRPS 0.01968902868413681
# Lead Time 30 hours | Observable v10 | Mean RMSD 1.8183896151411418 | Std RMSD 0.318255549617783
# Lead Time 30 hours | Observable v10 | Mean ACC 0.6784425099829304 | Std ACC 0.17292797748305458
# Lead Time 30 hours | Observable v10 | Mean CRPS 0.03082697289513397 | Std CRPS 0.02813879493537096
# Lead Time 36 hours | Observable z | Mean RMSD 131.80668010819133 | Std RMSD 47.98205221261546
# Lead Time 36 hours | Observable z | Mean ACC 0.5752235375292132 | Std ACC 0.2881577560423971
# Lead Time 36 hours | Observable z | Mean CRPS 0.032171872073793385 | Std CRPS 0.028969811803911862
# Lead Time 36 hours | Observable t | Mean RMSD 1.7984496567818151 | Std RMSD 0.3697464232839169
# Lead Time 36 hours | Observable t | Mean ACC 0.7520716660305404 | Std ACC 0.18759484687387343
# Lead Time 36 hours | Observable t | Mean CRPS 0.02782312724530001 | Std CRPS 0.026715652205482023
# Lead Time 36 hours | Observable t2m | Mean RMSD 2.1509677430187497 | Std RMSD 0.5402498595602289
# Lead Time 36 hours | Observable t2m | Mean ACC 0.739698182959481 | Std ACC 0.20047586764591513
# Lead Time 36 hours | Observable t2m | Mean CRPS 0.025593004585781447 | Std CRPS 0.027568978181693536
# Lead Time 36 hours | Observable u10 | Mean RMSD 1.6713225429843972 | Std RMSD 0.36079251178732435
# Lead Time 36 hours | Observable u10 | Mean ACC 0.614680157174486 | Std ACC 0.19045540094718097
# Lead Time 36 hours | Observable u10 | Mean CRPS 0.02240420747209616 | Std CRPS 0.02050368054159445
# Lead Time 36 hours | Observable v10 | Mean RMSD 1.9293618480965806 | Std RMSD 0.3782473422344702
# Lead Time 36 hours | Observable v10 | Mean ACC 0.6383661275796615 | Std ACC 0.196999158976984
# Lead Time 36 hours | Observable v10 | Mean CRPS 0.03305728477466347 | Std CRPS 0.031706571963361775
# Lead Time 42 hours | Observable z | Mean RMSD 145.15291515953191 | Std RMSD 47.29187851362951
# Lead Time 42 hours | Observable z | Mean ACC 0.46795672837895286 | Std ACC 0.3418694901716058
# Lead Time 42 hours | Observable z | Mean CRPS 0.034321719489530424 | Std CRPS 0.03075704189010135
# Lead Time 42 hours | Observable t | Mean RMSD 1.990004924078118 | Std RMSD 0.41793513766354384
# Lead Time 42 hours | Observable t | Mean ACC 0.6704488576928965 | Std ACC 0.23723326137858033
# Lead Time 42 hours | Observable t | Mean CRPS 0.03077918283546783 | Std CRPS 0.03011580659496545
# Lead Time 42 hours | Observable t2m | Mean RMSD 2.388118737162302 | Std RMSD 0.6928606772992779
# Lead Time 42 hours | Observable t2m | Mean ACC 0.6494474486538828 | Std ACC 0.3024939918455247
# Lead Time 42 hours | Observable t2m | Mean CRPS 0.028427267799680616 | Std CRPS 0.03204467300272308
# Lead Time 42 hours | Observable u10 | Mean RMSD 1.8958122580854653 | Std RMSD 0.421246153639263
# Lead Time 42 hours | Observable u10 | Mean ACC 0.58179326534144 | Std ACC 0.21218502494711752
# Lead Time 42 hours | Observable u10 | Mean CRPS 0.025791077660403273 | Std CRPS 0.02315620224402159
# Lead Time 42 hours | Observable v10 | Mean RMSD 2.153686146550362 | Std RMSD 0.43816803178482633
# Lead Time 42 hours | Observable v10 | Mean ACC 0.5813636296471871 | Std ACC 0.2273598778144785
# Lead Time 42 hours | Observable v10 | Mean CRPS 0.03713194874927659 | Std CRPS 0.03526308678403603
# Results have been saved to evaluation_metrics.csv
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\Desktop\CMU Africa\Fall 2024\Introduction to Deep Learning\Research Project\ClimODE\evaluation_region.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(str(cwd) + args.model_path, map_location=torch.device('cpu')))

# %%
# !python evaluation_region_seresnet.py --spectral 0 --scale 0 --region EastAfrica --batch_size 8 --model_path "\\tests\\region\\east africa\\se resnet\\ClimODE_region_EastAfrica_euler_0_model_35.pt"
# Out:
# ^C
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\groupers.py:326: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   self.index_grouper = pd.Grouper(
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\xarray\core\indexes.py:561: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   flat_indexer = index.get_indexer(flat_labels, method=method, tolerance=tolerance)
# c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\torch\nn\init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# c:\Users\robot\Desktop\CMU Africa\Fall 2024\Introduction to Deep Learning\Research Project\ClimODE\evaluation_region_seresnet.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(str(cwd) + args.model_path, map_location=torch.device('cpu')))
# ############################ Data is loading ###########################
# ['c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/geopotential_500/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/temperature_850/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/2m_temperature/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/10m_u_component_of_wind/*.nc', 'c:\\Users\\robot\\Desktop\\CMU Africa\\Fall 2024\\Introduction to Deep Learning\\Research Project\\ClimODE/era5_data/10m_v_component_of_wind/*.nc']
# Length of training data 1460
# Length of validation data 1460
# Length of testing data 1460
# ClimODE_uncertain_region_SEResNet(
#   (vel_f): Climate_SEResNet_2D(
#     (layer_cnn): ModuleList(
#       (0): Sequential(
#         (0): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (2): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (3): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (4): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=4, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=64, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=4, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=64, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (2): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=4, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=64, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (2): Sequential(
#         (0): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=10, out_features=0, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=0, out_features=10, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Sequential(
#             (0): Conv2d(64, 10, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=10, out_features=0, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=0, out_features=10, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#     )
#     (activation_cnn): ModuleList()
#   )
#   (vel_att): Self_attn_conv_reg(
#     (query): Sequential(
#       (0): boundarypad()
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.3)
#       (3): boundarypad()
#       (4): Conv2d(32, 8, kernel_size=(3, 3), stride=(1, 1))
#       (5): LeakyReLU(negative_slope=0.3)
#       (6): boundarypad()
#       (7): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     )
#     (key): Sequential(
#       (0): boundarypad()
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2))
#       (2): LeakyReLU(negative_slope=0.3)
#       (3): boundarypad()
#       (4): Conv2d(32, 8, kernel_size=(3, 3), stride=(2, 2))
#       (5): LeakyReLU(negative_slope=0.3)
#       (6): boundarypad()
#       (7): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     )
#     (value): Sequential(
#       (0): boundarypad()
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(2, 2))
#       (2): LeakyReLU(negative_slope=0.3)
#       (3): boundarypad()
#       (4): Conv2d(32, 10, kernel_size=(3, 3), stride=(2, 2))
#       (5): LeakyReLU(negative_slope=0.3)
#       (6): boundarypad()
#       (7): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#     )
#     (post_map): Sequential(
#       (0): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (noise_net): Climate_SEResNet_2D(
#     (layer_cnn): ModuleList(
#       (0): Sequential(
#         (0): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(43, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Sequential(
#             (0): Conv2d(43, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (2): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=8, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=128, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (1): Sequential(
#         (0): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=4, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=64, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=4, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=64, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#       (2): Sequential(
#         (0): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(64, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=10, out_features=0, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=0, out_features=10, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Sequential(
#             (0): Conv2d(64, 10, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#         (1): SEResNetBlock(
#           (activation): LeakyReLU(negative_slope=0.3)
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (se_layer): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=10, out_features=0, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=0, out_features=10, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (drop): Dropout(p=0.2, inplace=False)
#           (shortcut): Identity()
#           (norm1): Identity()
#           (norm2): Identity()
#         )
#       )
#     )
#     (activation_cnn): ModuleList()
#   )
# )
# Lead Time 6 hours | Observable z | Mean RMSD 60.295101651377834 | Std RMSD 22.23866596246594
# Lead Time 6 hours | Observable z | Mean ACC 0.8881305891962348 | Std ACC 0.09290907280416515
# Lead Time 6 hours | Observable z | Mean CRPS 0.01919345718416318 | Std CRPS 0.006164758811710747
# Lead Time 6 hours | Observable t | Mean RMSD 1.1052116561912615 | Std RMSD 0.2511893558417341
# Lead Time 6 hours | Observable t | Mean ACC 0.9192727411609216 | Std ACC 0.05898069021848013
# Lead Time 6 hours | Observable t | Mean CRPS 0.02103903693637133 | Std CRPS 0.009389452015563364
# Lead Time 6 hours | Observable t2m | Mean RMSD 1.67935288338924 | Std RMSD 0.47702382789464254
# Lead Time 6 hours | Observable t2m | Mean ACC 0.8445035761630567 | Std ACC 0.10555188822550363
# Lead Time 6 hours | Observable t2m | Mean CRPS 0.02389683095929398 | Std CRPS 0.013030952616659548
# Lead Time 6 hours | Observable u10 | Mean RMSD 1.3257500849130444 | Std RMSD 0.25459162772635824
# Lead Time 6 hours | Observable u10 | Mean ACC 0.7575057382745317 | Std ACC 0.13326476232629625
# Lead Time 6 hours | Observable u10 | Mean CRPS 0.0223217834369712 | Std CRPS 0.009046515410594784
# Lead Time 6 hours | Observable v10 | Mean RMSD 1.3956859235158183 | Std RMSD 0.28071461329120867
# Lead Time 6 hours | Observable v10 | Mean ACC 0.8046023354293483 | Std ACC 0.11551970510679978
# Lead Time 6 hours | Observable v10 | Mean CRPS 0.026696185093935468 | Std CRPS 0.014476646843195998
# Lead Time 12 hours | Observable z | Mean RMSD 89.65840491722284 | Std RMSD 30.53026480543266
# Lead Time 12 hours | Observable z | Mean ACC 0.8136968342219291 | Std ACC 0.16202402204973054
# Lead Time 12 hours | Observable z | Mean CRPS 0.02486804120868435 | Std CRPS 0.009640722108604028
# Lead Time 12 hours | Observable t | Mean RMSD 1.3084255078309044 | Std RMSD 0.2780195401184852
# Lead Time 12 hours | Observable t | Mean ACC 0.8755687441727248 | Std ACC 0.09246959751912885
# Lead Time 12 hours | Observable t | Mean CRPS 0.024177610401332393 | Std CRPS 0.011032980850593888
# Lead Time 12 hours | Observable t2m | Mean RMSD 1.8223759074009636 | Std RMSD 0.5357346226455623
# Lead Time 12 hours | Observable t2m | Mean ACC 0.7778369084879969 | Std ACC 0.16979495409731007
# Lead Time 12 hours | Observable t2m | Mean CRPS 0.02581325442030086 | Std CRPS 0.014281521932308935
# Lead Time 12 hours | Observable u10 | Mean RMSD 1.4166541123393814 | Std RMSD 0.3227725646649946
# Lead Time 12 hours | Observable u10 | Mean ACC 0.7087751080407438 | Std ACC 0.1500995914222257
# Lead Time 12 hours | Observable u10 | Mean CRPS 0.023435137923607494 | Std CRPS 0.010163531908471529
# Lead Time 12 hours | Observable v10 | Mean RMSD 1.5981719765047366 | Std RMSD 0.3653630987490444
# Lead Time 12 hours | Observable v10 | Mean ACC 0.7253490490912816 | Std ACC 0.16200557796953988
# Lead Time 12 hours | Observable v10 | Mean CRPS 0.029875617708245275 | Std CRPS 0.017630135805128407
# Lead Time 18 hours | Observable z | Mean RMSD 76.03750698998834 | Std RMSD 25.1890780850561
# Lead Time 18 hours | Observable z | Mean ACC 0.8190070907236797 | Std ACC 0.1383512824994583
# Lead Time 18 hours | Observable z | Mean CRPS 0.02351518417239752 | Std CRPS 0.008477649130056573
# Lead Time 18 hours | Observable t | Mean RMSD 1.4459081573320611 | Std RMSD 0.3134402374840799
# Lead Time 18 hours | Observable t | Mean ACC 0.8319367939779605 | Std ACC 0.11816094582773479
# Lead Time 18 hours | Observable t | Mean CRPS 0.026197752277744464 | Std CRPS 0.01270758068287726
# Lead Time 18 hours | Observable t2m | Mean RMSD 2.0347713762870576 | Std RMSD 0.6207451549525871
# Lead Time 18 hours | Observable t2m | Mean ACC 0.7023773549641562 | Std ACC 0.25277597249276856
# Lead Time 18 hours | Observable t2m | Mean CRPS 0.027997368776038395 | Std CRPS 0.01626330517795217
# Lead Time 18 hours | Observable u10 | Mean RMSD 1.5600338604183759 | Std RMSD 0.39974585715293015
# Lead Time 18 hours | Observable u10 | Mean ACC 0.7246891466508781 | Std ACC 0.14675611255017257
# Lead Time 18 hours | Observable u10 | Mean CRPS 0.02512652702436485 | Std CRPS 0.01208096013536436
# Lead Time 18 hours | Observable v10 | Mean RMSD 1.698740406457389 | Std RMSD 0.35612112484896435
# Lead Time 18 hours | Observable v10 | Mean ACC 0.7318462822893891 | Std ACC 0.16160763427210045
# Lead Time 18 hours | Observable v10 | Mean CRPS 0.03130230720834515 | Std CRPS 0.02023706912172708
# Lead Time 24 hours | Observable z | Mean RMSD 83.24042358568963 | Std RMSD 29.214717022936266
# Lead Time 24 hours | Observable z | Mean ACC 0.7932207865232513 | Std ACC 0.1745888019285811
# Lead Time 24 hours | Observable z | Mean CRPS 0.02515816577611771 | Std CRPS 0.010230130449411358
# Lead Time 24 hours | Observable t | Mean RMSD 1.4393785879954737 | Std RMSD 0.27732917971786336
# Lead Time 24 hours | Observable t | Mean ACC 0.882530934641772 | Std ACC 0.08068235240896743
# Lead Time 24 hours | Observable t | Mean CRPS 0.026106412714439375 | Std CRPS 0.013122645951667017
# Lead Time 24 hours | Observable t2m | Mean RMSD 1.7200760925154885 | Std RMSD 0.3390786604719192
# Lead Time 24 hours | Observable t2m | Mean ACC 0.901007084739301 | Std ACC 0.05993075406094464
# Lead Time 24 hours | Observable t2m | Mean CRPS 0.025366309560315596 | Std CRPS 0.012607360479340185
# Lead Time 24 hours | Observable u10 | Mean RMSD 1.4592606909152175 | Std RMSD 0.3217518255967704
# Lead Time 24 hours | Observable u10 | Mean ACC 0.7811101124372775 | Std ACC 0.11762823106125092
# Lead Time 24 hours | Observable u10 | Mean CRPS 0.024043109107039395 | Std CRPS 0.01172708084180774
# Lead Time 24 hours | Observable v10 | Mean RMSD 1.5610572373498168 | Std RMSD 0.35092976040791046
# Lead Time 24 hours | Observable v10 | Mean ACC 0.7872350930812472 | Std ACC 0.14597305260053497
# Lead Time 24 hours | Observable v10 | Mean CRPS 0.029352167327890977 | Std CRPS 0.0195977360638357
# Lead Time 30 hours | Observable z | Mean RMSD 96.16130987920377 | Std RMSD 36.95464113469072
# Lead Time 30 hours | Observable z | Mean ACC 0.7384367610337342 | Std ACC 0.20827531382687337
# Lead Time 30 hours | Observable z | Mean CRPS 0.027892235421764326 | Std CRPS 0.012190310451529693
# Lead Time 30 hours | Observable t | Mean RMSD 1.6098913032397972 | Std RMSD 0.33976241865004025
# Lead Time 30 hours | Observable t | Mean ACC 0.8266477262165595 | Std ACC 0.12426485916136255
# Lead Time 30 hours | Observable t | Mean CRPS 0.028273385901676325 | Std CRPS 0.014966513530223505
# Lead Time 30 hours | Observable t2m | Mean RMSD 1.8964193249887324 | Std RMSD 0.4680649758498449
# Lead Time 30 hours | Observable t2m | Mean ACC 0.7700271377500688 | Std ACC 0.16994944677677082
# Lead Time 30 hours | Observable t2m | Mean CRPS 0.026692014470693533 | Std CRPS 0.01458381341374245
# Lead Time 30 hours | Observable u10 | Mean RMSD 1.592285131696119 | Std RMSD 0.32939783325842464
# Lead Time 30 hours | Observable u10 | Mean ACC 0.6521316110258427 | Std ACC 0.18196905290636653
# Lead Time 30 hours | Observable u10 | Mean CRPS 0.02565258354599271 | Std CRPS 0.012127617019210902
# Lead Time 30 hours | Observable v10 | Mean RMSD 1.7791541017001575 | Std RMSD 0.37047236948135653
# Lead Time 30 hours | Observable v10 | Mean ACC 0.6744457930957536 | Std ACC 0.19842634516098726
# Lead Time 30 hours | Observable v10 | Mean CRPS 0.03284005207318286 | Std CRPS 0.020277425079518345
# Lead Time 36 hours | Observable z | Mean RMSD 117.18557152486424 | Std RMSD 41.78114692526108
# Lead Time 36 hours | Observable z | Mean ACC 0.6525284515624873 | Std ACC 0.2600052834184439
# Lead Time 36 hours | Observable z | Mean CRPS 0.031960128721111085 | Std CRPS 0.014790475197657981
# Lead Time 36 hours | Observable t | Mean RMSD 1.6819557050881444 | Std RMSD 0.36742034339435575
# Lead Time 36 hours | Observable t | Mean ACC 0.792171712800783 | Std ACC 0.14901298010961822
# Lead Time 36 hours | Observable t | Mean CRPS 0.029485659736325803 | Std CRPS 0.015696236736628608
# Lead Time 36 hours | Observable t2m | Mean RMSD 1.9486112192166658 | Std RMSD 0.5303098424283818
# Lead Time 36 hours | Observable t2m | Mean ACC 0.7330804147751423 | Std ACC 0.20372238679885576
# Lead Time 36 hours | Observable t2m | Mean CRPS 0.027180516603272562 | Std CRPS 0.015404753481837856
# Lead Time 36 hours | Observable u10 | Mean RMSD 1.6290211933875998 | Std RMSD 0.35493997241271047
# Lead Time 36 hours | Observable u10 | Mean ACC 0.6135154668048276 | Std ACC 0.19381552343092975
# Lead Time 36 hours | Observable u10 | Mean CRPS 0.025823121759176608 | Std CRPS 0.012349374686162507
# Lead Time 36 hours | Observable v10 | Mean RMSD 1.9122210613085644 | Std RMSD 0.4164256008433933
# Lead Time 36 hours | Observable v10 | Mean ACC 0.6064450724361887 | Std ACC 0.23570476870648
# Lead Time 36 hours | Observable v10 | Mean CRPS 0.034427382510241925 | Std CRPS 0.022851823300177664
# Lead Time 42 hours | Observable z | Mean RMSD 111.46589516873831 | Std RMSD 42.48395507786169
# Lead Time 42 hours | Observable z | Mean ACC 0.6468091155629183 | Std ACC 0.26303625489596966
# Lead Time 42 hours | Observable z | Mean CRPS 0.0314416455383268 | Std CRPS 0.015262654825944572
# Lead Time 42 hours | Observable t | Mean RMSD 1.749526324941849 | Std RMSD 0.38863833314113116
# Lead Time 42 hours | Observable t | Mean ACC 0.7611630958158973 | Std ACC 0.15658698410373137
# Lead Time 42 hours | Observable t | Mean CRPS 0.03038331758671832 | Std CRPS 0.01658696616981613
# Lead Time 42 hours | Observable t2m | Mean RMSD 2.28163020499505 | Std RMSD 0.6377504152364554
# Lead Time 42 hours | Observable t2m | Mean ACC 0.6515407516369457 | Std ACC 0.2824650140413497
# Lead Time 42 hours | Observable t2m | Mean CRPS 0.030069618219339154 | Std CRPS 0.019620234497587364
# Lead Time 42 hours | Observable u10 | Mean RMSD 1.8040473335514648 | Std RMSD 0.4238535621491016
# Lead Time 42 hours | Observable u10 | Mean ACC 0.6276599213259625 | Std ACC 0.20015182603777693
# Lead Time 42 hours | Observable u10 | Mean CRPS 0.02754489835120121 | Std CRPS 0.014763490259968001
# Lead Time 42 hours | Observable v10 | Mean RMSD 2.0663981712719854 | Std RMSD 0.44519527050294
# Lead Time 42 hours | Observable v10 | Mean ACC 0.6049763924098606 | Std ACC 0.23801323610572017
# Lead Time 42 hours | Observable v10 | Mean CRPS 0.03636600095241783 | Std CRPS 0.027151760428721854
# Results have been saved to evaluation_metrics.csv

# %% [markdown]
# ### Evaluating se resnet

# %%
# !python evaluation_region_seresnet.py --spectral 0 --scale 0 --region EastAfrica --batch_size 8 --model_path "\\tests\\region\\east africa\\se resnet\\ClimODE_region_EastAfrica_euler_0_model_.pt"

# %% [markdown]
# ### Evaluating global context block

# %%
# !python evaluation_region_gcb.py --spectral 0 --scale 0 --region EastAfrica --batch_size 8 --model_path "\\tests\\region\\east africa\\global_context_block\\ClimODE_region_EastAfrica_euler_0_model_.pt"

# %% [markdown]
# ### Evaluating Coordinate attention architecture

# %%
# !python evaluation_region_coord_att.py --spectral 0 --scale 0 --region EastAfrica --batch_size 8 --model_path "\\tests\\region\\east africa\\coordinate attention block\\ClimODE_region_EastAfrica_euler_0_model_.pt"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Helper function to plot RMSE, ACC, and CRPS for a given dataset
def plot_metrics(data, model_name, ax_rmse, ax_acc, ax_crps, color, marker):
    observables = data['Observable'].unique()
    lead_times = sorted(data['Lead Time (hours)'].unique())

    for i, obs in enumerate(observables):
        obs_data = data[data['Observable'] == obs]
        # Plot RMSE
        ax_rmse[i].errorbar(
            lead_times, obs_data['Mean RMSD'], yerr=obs_data['Std RMSD'],
            label=model_name, color=color, marker=marker, capsize=3
        )
        # Plot ACC
        ax_acc[i].errorbar(
            lead_times, obs_data['Mean ACC'], yerr=obs_data['Std ACC'],
            label=model_name, color=color, marker=marker, capsize=3
        )
        # Plot CRPS
        ax_crps[i].errorbar(
            lead_times, obs_data['Mean CRPS'], yerr=obs_data['Std CRPS'],
            label=model_name, color=color, marker=marker, capsize=3
        )

# Function to load data for each model and plot RMSE, ACC, and CRPS
def load_and_plot(csv_files, model_names, colors, markers, ax_rmse, ax_acc, ax_crps):
    for model_name, file_path in zip(model_names, csv_files):
        # Load the dataset
        data = pd.read_csv(file_path)
        # Plot RMSE, ACC, and CRPS for the dataset
        plot_metrics(data, model_name, ax_rmse, ax_acc, ax_crps, colors[model_name], markers[model_name])

# Paths to CSV files for NODE, ClimaX, FCN, and ClimODE
csv_files = [
    "./evaluations/evaluation_metrics_baseline.csv",    # Replace with the actual file path for NODE
    "./evaluations/evaluation_metrics_c_att.csv",      # Replace with the actual file path for ClimaX
    "./evaluations/evaluation_metrics_gcb.csv",        # Replace with the actual file path for FCN
    "./evaluations/evaluation_metrics_seresnet.csv"    # Replace with the actual file path for ClimODE
]

# Model names and properties
model_names = ["Baseline ClimODE", "Coordinate Attention Model + ClimODE", "Global Context Block + ClimODE", "SE ResNet + ClimODE"]
model_colors = {"Baseline ClimODE": "blue", "Coordinate Attention Model + ClimODE": "purple", "Global Context Block + ClimODE": "red", "SE ResNet + ClimODE": "orange"}
model_markers = {"Baseline ClimODE": "o", "Coordinate Attention Model + ClimODE": "^", "Global Context Block + ClimODE": "s", "SE ResNet + ClimODE": "D"}

# Prepare subplots for RMSE, ACC, and CRPS
n_obs = 5  # Number of observables (z, t, t2m, u10, v10)
fig, axes = plt.subplots(3, n_obs, figsize=(15, 9), sharex=True)

# Load data for each model and plot
load_and_plot(csv_files, model_names, model_colors, model_markers, axes[0], axes[1], axes[2])

# Add titles, labels, and legends
observables = ['z', 't', 't2m', 'u10', 'v10']  # Observable variables
for i, obs in enumerate(observables):
    axes[0][i].set_title(obs)
    axes[0][i].set_ylabel('RMSE')
    axes[1][i].set_ylabel('ACC')
    axes[2][i].set_ylabel('CRPS')
    axes[2][i].set_xlabel('Lead Time (hr)')

# Set shared legend
handles, labels = axes[0][0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=len(model_colors), bbox_to_anchor=(0.5, 1.02))

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ## Model Summary

# %%
import pandas as pd

# Load the data from the CSV files
data = {}
for file_path, model_name in zip(csv_files, model_names):
    df = pd.read_csv(file_path)
    data[model_name] = df

# Create the table
table_data = []
for observable in ['z', 't', 't2m', 'u10', 'v10']:
    row = [observable]
    for model_name in model_names:
        df = data[model_name]
        row.append(df[df['Observable'] == observable]['Mean RMSD'].values[0])
        row.append(df[df['Observable'] == observable]['Mean ACC'].values[0])
        row.append(df[df['Observable'] == observable]['Mean CRPS'].values[0])
    table_data.append(row)

# Create the table DataFrame
table = pd.DataFrame(table_data, columns=['Observable'] + [f'{name}\nRMSE' for name in model_names] + [f'{name}\nACC' for name in model_names] + [f'{name}\nCRPS' for name in model_names])

display(table)
# Out:
#   Observable  Baseline ClimODE\nRMSE  \
# 0          z               55.641476
# 1          t                0.952248
# 2        t2m                1.450396
# 3        u10                1.471031
# 4        v10                1.522349
#
#    Coordinate Attention Model + ClimODE\nRMSE  \
# 0                                    0.886869
# 1                                    0.938832
# 2                                    0.886077
# 3                                    0.754775
# 4                                    0.802821
#
#    Global Context Block + ClimODE\nRMSE  SE ResNet + ClimODE\nRMSE  \
# 0                              0.013360                  62.421732
# 1                              0.014350                   0.944593
# 2                              0.017345                   1.458294
# 3                              0.019654                   1.224778
# 4                              0.025862                   1.323544
#
#    Baseline ClimODE\nACC  Coordinate Attention Model + ClimODE\nACC  \
# 0               0.863117                                   0.015228
# 1               0.939943                                   0.014416
# 2               0.872639                                   0.017479
# 3               0.807384                                   0.016427
# 4               0.826560                                   0.022910
#
#    Global Context Block + ClimODE\nACC  SE ResNet + ClimODE\nACC  \
# 0                            78.385511                  0.787061
# 1                             1.017424                  0.932143
# 2                             1.705635                  0.829658
# 3                             1.553544                  0.727886
# 4                             1.612512                  0.780505
#
#    Baseline ClimODE\nCRPS  Coordinate Attention Model + ClimODE\nCRPS  \
# 0                0.024177                                   59.697808
# 1                0.019304                                    0.888813
# 2                0.023058                                    1.382788
# 3                0.024492                                    1.191635
# 4                0.030335                                    1.261426
#
#    Global Context Block + ClimODE\nCRPS  SE ResNet + ClimODE\nCRPS
# 0                              0.886866                   0.014604
# 1                              0.946175                   0.013519
# 2                              0.892222                   0.016298
# 3                              0.819557                   0.015956
# 4                              0.841710                   0.021923

# %%
data = {}
for file_path, model_name in zip(csv_files, model_names):
    df = pd.read_csv(file_path)
    data[model_name] = df

# Create the table data
table_data = []
for observable in ['z', 't', 't2m', 'u10', 'v10']:
    row = [observable]
    for model_name in model_names:
        df = data[model_name]
        row.extend([
            df[df['Observable'] == observable]['Mean RMSD'].values[0],
            df[df['Observable'] == observable]['Mean ACC'].values[0],
            df[df['Observable'] == observable]['Mean CRPS'].values[0]
        ])
    table_data.append(row)

# Create multi-index column headers
metrics = ["RMSE", "ACC", "CRPS"]
columns = pd.MultiIndex.from_product([metrics, model_names], names=["Metric", "Model"])

# Create the DataFrame
table = pd.DataFrame(table_data, columns=["Observable"] + list(columns))

# Highlight the best scores (wrap the best score in brackets)
for metric in metrics:
    for observable_idx in range(len(table)):
        # Get the relevant metric columns for each observable
        metric_columns = table.loc[observable_idx, (metric, slice(None))]
        
        # Find the index of the best score: min for RMSE and CRPS, max for ACC
        if metric == "RMSE" or metric == "CRPS":
            best_value_idx = metric_columns.idxmin()  # For RMSE and CRPS, lower is better
        else:
            best_value_idx = metric_columns.idxmax()  # For ACC, higher is better
        
        # Wrap the best value in brackets
        best_value = table.loc[observable_idx, best_value_idx]
        table.loc[observable_idx, best_value_idx] = f"[{best_value}]"

# Display the table
print(table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 30
#      27 for metric in metrics:
#      28     for observable_idx in range(len(table)):
#      29         # Get the relevant metric columns for each observable
# ---> 30         metric_columns = table.loc[observable_idx, (metric, slice(None))]
#      32         # Find the index of the best score: min for RMSE and CRPS, max for ACC
#      33         if metric == "RMSE" or metric == "CRPS":
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexes\base.py:6195, in Index._get_indexer_strict(self, key, axis_name)
#    6192     keyarr = com.asarray_tuplesafe(keyarr)
#    6194 if self._index_as_unique:
# -> 6195     indexer = self.get_indexer_for(keyarr)
#    6196     keyarr = self.reindex(keyarr)[0]
#    6197 else:
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexes\base.py:6182, in Index.get_indexer_for(self, target)
#    6164 """
#    6165 Guaranteed return of an indexer even when non-unique.
#    6166
#    (...)
#    6179 array([0, 2])
#    6180 """
#    6181 if self._index_as_unique:
# -> 6182     return self.get_indexer(target)
#    6183 indexer, _ = self.get_indexer_non_unique(target)
#    6184 return indexer
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexes\base.py:3953, in Index.get_indexer(self, target, method, limit, tolerance)
#    3948     target = target.astype(dtype, copy=False)
#    3949     return this._get_indexer(
#    3950         target, method=method, limit=limit, tolerance=tolerance
#    3951     )
# -> 3953 return self._get_indexer(target, method, limit, tolerance)
#
# File c:\Users\robot\anaconda3\envs\climode_env\lib\site-packages\pandas\core\indexes\base.py:3980, in Index._get_indexer(self, target, method, limit, tolerance)
#    3977     else:
#    3978         tgt_values = target._get_engine_target()
# -> 3980     indexer = self._engine.get_indexer(tgt_values)
#    3982 return ensure_platform_int(indexer)
#
# File index.pyx:351, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7132, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'slice'

# %%
table.to_csv("results.csv")
